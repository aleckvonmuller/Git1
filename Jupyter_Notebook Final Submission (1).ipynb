# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # **Aleck von Muller**
# I want to become a Data Scientist and Software Developer

# %% [markdown]
# *I am interested in data science because it combines the beauty of numbers and data, and my love of math, engineering, and correlations.*

# %% [markdown]
# ### The code below is to represent basic calculations in Jupyter Notebook, following PEMDAS order of operations.

# %%
9 * (9 - 3) + 5
# Out:
# 59

# %% [markdown]
# The | Most | Amazing | Table
# --- | --- | --- | ---
# Check | This | <a href="https://dataplatform.cloud.ibm.com/gallery"> Link</a> | Out
# This | is | Super | Neat
#
# >Bulleted list incoming!
#
# - Pew!
#     - Pew!
#         - Pew!
#
# ![TheCatligrapher2047121-1024x540.jpg](attachment:777cc1df-e2fd-4406-b093-4259c2ab3824.jpg)
